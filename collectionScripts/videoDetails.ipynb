# %%
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

import urllib.parse as p
import re
import os
import pickle
from google.auth.exceptions import RefreshError
import logging
import pandas as pd 

logging.basicConfig(level=logging.WARNING)
logger = logging.getLogger(__name__)

SCOPES = ["https://www.googleapis.com/auth/youtube.force-ssl"]

# %%
def youtube_authenticate():
    os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"
    api_service_name = "youtube"
    api_version = "v3"
    client_secrets_file = r'D:\2A\2A\mods207\code_secret_client.json'
    creds = None
    # the file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first time
    if os.path.exists("token.pickle"):
        with open("token.pickle", "rb") as token:
            creds = pickle.load(token)
    # if there are no (valid) credentials availablle, let the user log in.
    if creds and creds.refresh_token:
        try:
            creds.refresh(Request())
        except RefreshError:
            logger.error("Credentials could not be refreshed, possibly the authorization was revoked by the user.")
            os.unlink('token.pickle')
            return
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            client_secrets_file, SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.pickle', 'wb') as token:
        pickle.dump(creds, token)
            
            


    return build(api_service_name, api_version, credentials=creds)

# authenticate to YouTube API
youtube = youtube_authenticate()

# %%
def get_video_id_by_url(url):
    """
    Return the Video ID from the video `url`
    """
    # split URL parts
    parsed_url = p.urlparse(url)
    # get the video ID by parsing the query of the URL
    video_id = p.parse_qs(parsed_url.query).get("v")
    if video_id:
        return video_id[0]
    else:
        raise Exception(f"Wasn't able to parse video URL: {url}")

# %%
def get_video_details(youtube, **kwargs):
    return youtube.videos().list(
        part="snippet,contentDetails,statistics",
        **kwargs
    ).execute()

# %%
def save_video_infos(video_response, df):
    items = video_response.get("items")[0]
    # get the snippet, statistics & content details from the video response
    snippet         = items["snippet"]
    statistics      = items["statistics"]
    content_details = items["contentDetails"]
    # get infos from the snippet
    channel_title = snippet["channelTitle"]
    title         = snippet["title"]
    description   = snippet["description"]
    publish_time  = snippet["publishedAt"]
    if "tags" in snippet : 
        key_words = snippet["tags"]
    else :
        key_words = []
        
    category      = snippet["categoryId"]
    # get stats infos
    if "commentCount" in statistics : 
        comment_count = statistics["commentCount"]
    else : 
        comment_count = -1

    if "likeCount" in statistics :
        like_count = statistics["likeCount"]
    else :
        like_count = -1
        
    favorite_count = statistics["favoriteCount"]
    view_count     = statistics["viewCount"]    
    # get duration from content detail  
    duration   = content_details["duration"]
    definition = content_details["definition"]
    caption    = content_details["caption"]
    licensed   = content_details["licensedContent"]
    # duration in the form of something like 'PT5H50M15S'
    # parsing it to be something like '5:50:15'
    parsed_duration = re.search(f"PT(\d+H)?(\d+M)?(\d+S)", duration)
    
    duration_str = ""
    if parsed_duration != None :
        for d in parsed_duration.groups():
            if d:
                duration_str += f"{d[:-1]}:"
        duration_str = duration_str.strip(":")
    
    df = df.append({"Title": title, "Description" : description, "Channel Title" : channel_title,
                    "Publish time" : publish_time, "Tags": key_words, "Category" : category, 
                    "Duration" : duration_str, "Number of comments" : comment_count, 
                    "Number of likes" : like_count, "Number of views" : view_count, 
                    "Number of favorites" : favorite_count, "Video quality" : definition,
                    "Licensed" : licensed} ,   ignore_index=True)
    return df

# %% [markdown]
# # Comments

# %%
def get_comments(youtube, **kwargs):
    return youtube.commentThreads().list(
        part="snippet",
        **kwargs
    ).execute()

# %%
# URL can be a channel or a video, to extract comments
url = "https://www.youtube.com/watch?v=CpZBJZYJKFE&ab_channel=Cyprien"
if "watch" in url:
    # that's a video
    video_id = get_video_id_by_url(url)
    params = {
        'videoId': video_id, 
        'maxResults': 2,
        'order': 'relevance', # default is 'time' (newest)
    }
else:
    # should be a channel
    channel_id = get_channel_id_by_url(url)
    params = {
        'allThreadsRelatedToChannelId': channel_id, 
        'maxResults': 2,
        'order': 'relevance', # default is 'time' (newest)
    }
# get the first 2 pages (2 API requests)
n_pages = 2
for i in range(n_pages):
    # make API call to get all comments from the channel (including posts & videos)
    response = get_comments(youtube, **params)
    items = response.get("items")
    # if items is empty, breakout of the loop
    if not items:
        break
    for item in items:
        comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
        updated_at = item["snippet"]["topLevelComment"]["snippet"]["updatedAt"]
        like_count = item["snippet"]["topLevelComment"]["snippet"]["likeCount"]
        comment_id = item["snippet"]["topLevelComment"]["id"]
        print(f"""\
        Comment: {comment}
        Likes: {like_count}
        Updated At: {updated_at}
        ==================================\
        """)
    if "nextPageToken" in response:
        # if there is a next page
        # add next page token to the params we pass to the function
        params["pageToken"] =  response["nextPageToken"]
    else:
        # must be end of comments!!!!
        break
    print("*"*70)
# Out:
#         Comment: N&#39;oubliez pas d&#39;utiliser mon lien pour la réduction sur l&#39;abonnement de 2 ans à NordVPN <a href="http://www.nordvpn.com/cyprien">http://www.nordvpn.com/cyprien</a> et merci pour vos messages ✌
#         Likes: 3142
#         Updated At: 2022-04-29T15:10:23Z
#         ==================================
#         Comment: Comme toujours : Masterclass. Quelle créativité folle, ça fait du bien de voir ça sur Youtube !! :)
#         Likes: 9310
#         Updated At: 2022-04-29T15:15:24Z
#         ==================================
# **********************************************************************
#         Comment: Toujours un plaisir de voir à quel point tu arrive à crée des personnages attachant sur un format si court, toujours plein de créativité, un vrai plaisir d’avoir ce genre de contenus sur YouTube.
#         Likes: 259
#         Updated At: 2022-05-04T04:05:34Z
#         ==================================
#         Comment: Masterclass de Cyprien comme d’habitude c’est créatif et innovant, un petit scénario derrière c’est super on passe toujours un bon moment.
#         Likes: 442
#         Updated At: 2022-05-03T12:36:40Z
#         ==================================
# **********************************************************************

# %%
def get_channel_videos(path, channel):
    
    channel_csv = pd.read_csv(path + channel)
    channel_csv.drop_duplicates(inplace=True)  # drop ducplicates 
    channel_csv.dropna(inplace=True)  # drop nan
    videos = channel_csv['videos'].apply(lambda x : str(x)) # all video urls are an str type
    videos = videos[videos.apply(lambda x : "https://www.youtube.com/watch?v" in x)] # keep only videos
    video_ids = videos.apply(lambda x : get_video_id_by_url(x)) # extract video id
    
    df = pd.DataFrame() 
    for video_id in video_ids :
        try :
            response = get_video_details(youtube, id=video_id)
            df = save_video_infos(response, df)
            #print("got details for", video_id)
            
        except Exception as inst:
            print(type(inst))    # the exception instance
            print(inst) 
            print("Error in video id ", video_id)
    
    return df

# %%
path = 'channelVideos/'
all_videos = os.listdir(path)

for channel in all_videos :
    df = get_channel_videos(path, channel)
    channel_videos = 'channel' + channel.split("_")[1] + 'videos.csv'
    df.to_csv(channel_videos, index=False)
    print('scrapped ', channel)
# Out:
# scrapped  channel_0_UCWeg2Pkate69NFdBeuRFTAw.csv
# scrapped  channel_10_UCp8Lmjx1i93YVokA4fNAs1g.csv
# scrapped  channel_11_UCgvqvBoSHB1ctlyyhoHrGwQ.csv
# scrapped  channel_12_UCo3i0nUzZjjLuM7VjAVz4zA.csv
# scrapped  channel_13_UCmPSwsooZq8an7xOLQQhAdw.csv
# scrapped  channel_14_UCDPK_MTu3uTUFJXRVcTJcEw.csv
# scrapped  channel_15_UCt6IQpsggvn6zmalhPglSEA.csv
# scrapped  channel_16_UC-69vhXlCa3XHbF8JHCQHfg.csv
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=lNyeQ60lPG4&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  lNyeQ60lPG4
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=gKD1ueEoTYk&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  gKD1ueEoTYk
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=wS9ohWjiEOo&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  wS9ohWjiEOo
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=5vFDuOhcJSU&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  5vFDuOhcJSU
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=IMfo6xQPIeA&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  IMfo6xQPIeA
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=D87MrO3E5M4&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  D87MrO3E5M4
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=tJWh0hzqsMo&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  tJWh0hzqsMo
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=yTsN6Dll7oA&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  yTsN6Dll7oA
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=cLexNx29fao&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  cLexNx29fao
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=TotBDReeeYk&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  TotBDReeeYk
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=8RK6HPwndwc&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  8RK6HPwndwc
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=qUrYb-15E78&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  qUrYb-15E78
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=m0g2c63Kayo&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  m0g2c63Kayo
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=CJYFX1zLrYQ&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  CJYFX1zLrYQ
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=TfyZ7SwqpJ0&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  TfyZ7SwqpJ0
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=YCPnXlekQgQ&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  YCPnXlekQgQ
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=FDpVEduyJ48&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  FDpVEduyJ48
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=CapjmydYJg4&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  CapjmydYJg4
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=u3ec4XbCbXc&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  u3ec4XbCbXc
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=xTfVDhb-ekQ&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  xTfVDhb-ekQ
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=xZE0tj_MR_Y&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  xZE0tj_MR_Y
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=iQH1CTc5TMk&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  iQH1CTc5TMk
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=3ufwFoYileM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  3ufwFoYileM
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=qVpxl1f8-Z8&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  qVpxl1f8-Z8
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=33Wd13UjVzg&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  33Wd13UjVzg
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=vbfWKLoHQfw&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  vbfWKLoHQfw
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=vgWJd1eswsI&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  vgWJd1eswsI
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=s5lZdtN7nXM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  s5lZdtN7nXM
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=2FxSEyumiRs&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  2FxSEyumiRs
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=Bt-eI8V7qh8&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  Bt-eI8V7qh8
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=1sjHGcMtIiU&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  1sjHGcMtIiU
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=p8-yBHC5tHs&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  p8-yBHC5tHs
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=CDnVL9gQWDA&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  CDnVL9gQWDA
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=7f0aJo1V3ww&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  7f0aJo1V3ww
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=2HGHEreXWSs&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  2HGHEreXWSs
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=JG60ukbugEo&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  JG60ukbugEo
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=M9hSkwQXF0A&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  M9hSkwQXF0A
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=2w0F49WrrqQ&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  2w0F49WrrqQ
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=r8oGI8bmiUY&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  r8oGI8bmiUY
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=XPzCcTf8tWE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  XPzCcTf8tWE
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=26C5mW7M0jw&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  26C5mW7M0jw
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=OMpUCU8z8mc&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  OMpUCU8z8mc
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=NZ7hMMHYWrM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  NZ7hMMHYWrM
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=cwsqjd6PyLs&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  cwsqjd6PyLs
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=ns8tQQcLOQU&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  ns8tQQcLOQU
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=AA-gbKy_ke4&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  AA-gbKy_ke4
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=3AGbyUZgJpw&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  3AGbyUZgJpw
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=FwKeOBcd9pM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  FwKeOBcd9pM
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=IZoHgcoyZac&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  IZoHgcoyZac
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=fShQZPl2sHw&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  fShQZPl2sHw
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=Vr_thnYLsWs&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  Vr_thnYLsWs
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=pLb2JDtEJMQ&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  pLb2JDtEJMQ
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=d5xsi_gFii4&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  d5xsi_gFii4
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=Z1tE21N8ym8&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  Z1tE21N8ym8
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=58zqSoF3Ubs&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  58zqSoF3Ubs
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=nnihPl-e85c&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  nnihPl-e85c
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=HViqwaq0U0Y&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  HViqwaq0U0Y
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=2bd1owLf1rc&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  2bd1owLf1rc
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=A-_LOvsMuwc&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  A-_LOvsMuwc
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=MYw1Qt2AxwY&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  MYw1Qt2AxwY
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=Yl-qmN1ey6s&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  Yl-qmN1ey6s
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=HsfBb5gEyrk&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  HsfBb5gEyrk
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=BJ93CcupdbQ&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  BJ93CcupdbQ
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=kCScmCkGYHw&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  kCScmCkGYHw
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=li7EL4aoVbI&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  li7EL4aoVbI
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=sKrOYj0pUqs&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  sKrOYj0pUqs
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=sP0EeCFuRjY&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  sP0EeCFuRjY
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=d69KBvalNOU&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  d69KBvalNOU
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=99Y47y-u-1Y&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  99Y47y-u-1Y
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=B_6F6JT-Uis&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  B_6F6JT-Uis
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=TkKu66uF15I&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  TkKu66uF15I
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=81UsmVTKJhw&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  81UsmVTKJhw
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=VECqU8VMzow&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  VECqU8VMzow
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=vrNlCn9I69c&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  vrNlCn9I69c
# <class 'googleapiclient.errors.HttpError'>
# ...
# Error in video id  flgzxuZeFQI
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=98EMIh_i2aU&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  98EMIh_i2aU
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=POBOw2iV6Vw&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  POBOw2iV6Vw
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=rF51J-B14jE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  rF51J-B14jE
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=Yvan4dCC7MU&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  Yvan4dCC7MU
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=Xg1haJhXzz8&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  Xg1haJhXzz8
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=FZ_2lZszuEA&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  FZ_2lZszuEA
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=tsuh9ZVVjIE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  tsuh9ZVVjIE
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=3ND_joCGrY4&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  3ND_joCGrY4
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=4D91Cp9zQDg&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  4D91Cp9zQDg
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=pJeM8DDSk1s&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  pJeM8DDSk1s
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=1UmMS2DDARc&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  1UmMS2DDARc
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=EHeGJk9rRzc&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  EHeGJk9rRzc
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=_2B31hzQl9o&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  _2B31hzQl9o
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=xg1Nn34qWzI&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  xg1Nn34qWzI
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=9eayJJt-8ds&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  9eayJJt-8ds
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=Q_lppH1-DuE&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  Q_lppH1-DuE
# <class 'googleapiclient.errors.HttpError'>
# <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=RRN5keKCqzw&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error in video id  RRN5keKCqzw
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20392\458194241.py in <module>
#       3
#       4 for channel in all_videos :
# ----> 5     df = get_channel_videos(path, channel)
#       6     channel_videos = 'channel' + channel.split("_")[1] + 'videos.csv'
#       7     df.to_csv(channel_videos, index=False)
#
# ~\AppData\Local\Temp\ipykernel_20392\2016242748.py in get_channel_videos(path, channel)
#      11     for video_id in video_ids :
#      12         try :
# ---> 13             response = get_video_details(youtube, id=video_id)
#      14             df = save_video_infos(response, df)
#      15             #print("got details for", video_id)
#
# ~\AppData\Local\Temp\ipykernel_20392\2055434514.py in get_video_details(youtube, **kwargs)
#       2     return youtube.videos().list(
#       3         part="snippet,contentDetails,statistics",
# ----> 4         **kwargs
#       5     ).execute()
#
# ~\anaconda3\envs\mods207\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     129                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     130                     logger.warning(message)
# --> 131             return wrapped(*args, **kwargs)
#     132
#     133         return positional_wrapper
#
# ~\anaconda3\envs\mods207\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     929             method=str(self.method),
#     930             body=self.body,
# --> 931             headers=self.headers,
#     932         )
#     933
#
# ~\anaconda3\envs\mods207\lib\site-packages\googleapiclient\http.py in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     188         try:
#     189             exception = None
# --> 190             resp, content = http.request(uri, method, *args, **kwargs)
#     191         # Retry on SSL errors and socket timeout errors.
#     192         except _ssl_SSLError as ssl_error:
#
# ~\anaconda3\envs\mods207\lib\site-packages\google_auth_httplib2.py in request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     223             redirections=redirections,
#     224             connection_type=connection_type,
# --> 225             **kwargs
#     226         )
#     227
#
# ~\anaconda3\envs\mods207\lib\site-packages\httplib2\__init__.py in request(self, uri, method, body, headers, redirections, connection_type)
#    1700                 else:
#    1701                     (response, content) = self._request(
# -> 1702                         conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1703                     )
#    1704         except Exception as e:
#
# ~\anaconda3\envs\mods207\lib\site-packages\httplib2\__init__.py in _request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1419             auth.request(method, request_uri, headers, body)
#    1420
# -> 1421         (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1422
#    1423         if auth:
#
# ~\anaconda3\envs\mods207\lib\site-packages\httplib2\__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#    1371                 pass
#    1372             try:
# -> 1373                 response = conn.getresponse()
#    1374             except (http.client.BadStatusLine, http.client.ResponseNotReady):
#    1375                 # If we get a BadStatusLine on the first try then that means
#
# ~\anaconda3\envs\mods207\lib\http\client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# ~\anaconda3\envs\mods207\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~\anaconda3\envs\mods207\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~\anaconda3\envs\mods207\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\anaconda3\envs\mods207\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\envs\mods207\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
